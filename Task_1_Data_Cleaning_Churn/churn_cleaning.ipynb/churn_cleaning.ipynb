# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv(r"C:\Users\Anthony Bannerman\Documents\Codveda-Internship-Data-Science\Task_1_Data_Cleaning_Churn\Churn Prdiction Data\churn-bigml-20.csv")

# Preview data
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# # Check categorical columns

# %%
# See the unique values in each categorical column to detect inconsistencies or typos:
print(df['State'].unique())
print(df['International plan'].unique())
print(df['Voice mail plan'].unique())
# Out:
# ['LA' 'IN' 'NY' 'SC' 'HI' 'AK' 'MI' 'ID' 'VA' 'WI' 'MN' 'VT' 'MT' 'MA'
#  'KY' 'CO' 'AZ' 'CA' 'WA' 'NE' 'OH' 'MO' 'AL' 'NH' 'NM' 'OR' 'TX' 'MS'
#  'WY' 'FL' 'KS' 'NC' 'SD' 'OK' 'CT' 'RI' 'DE' 'UT' 'NV' 'DC' 'ME' 'IL'
#  'NJ' 'MD' 'WV' 'PA' 'ND' 'AR' 'TN' 'IA' 'GA']
# ['No' 'Yes']
# ['No' 'Yes']

# %% [markdown]
# # Check numerical columns

# %%
df.describe()
# Out:
#        Account length   Area code  Number vmail messages  Total day minutes  \
# count      667.000000  667.000000             667.000000         667.000000
# mean       102.841079  436.157421               8.407796         180.948126
# std         40.819480   41.783305              13.994480          55.508628
# min          1.000000  408.000000               0.000000          25.900000
# 25%         76.000000  408.000000               0.000000         146.250000
# 50%        102.000000  415.000000               0.000000         178.300000
# 75%        128.000000  415.000000              20.000000         220.700000
# max        232.000000  510.000000              51.000000         334.300000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count       667.000000        667.000000         667.000000       667.000000
# mean        100.937031         30.761769         203.355322       100.476762
# ...

# %% [markdown]
# # Next steps for these categorical columns:

# %%
# Convert Yes/No to 1/0 for modeling:
df['International plan'] = df['International plan'].map({'Yes':1, 'No':0})
df['Voice mail plan'] = df['Voice mail plan'].map({'Yes':1, 'No':0})
df['Churn'] = df['Churn'].astype(int)  # True/False → 1/0

# %%
# Use one-hot encoding or label encoding depending on the algorithm:
df = pd.get_dummies(df, columns=['State'], drop_first=True)

# %%
# the cleaned data
df.head()
# Out:
#    Account length  Area code  International plan  Voice mail plan  \
# 0             117        408                   0                0
# 1              65        415                   0                0
# 2             161        415                   0                0
# 3             111        415                   0                0
# 4              49        510                   0                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  ...  State_SD  \
# 0             31.37              351.6               80  ...     False
# ...

# %%
# Check all columns
print(df.columns)

# Check if Churn exists
print('Churn' in df.columns)

# Preview the first few rows of Churn
df['Churn'].head()
# Out:
# Index(['Account length', 'Area code', 'International plan', 'Voice mail plan',
#        'Number vmail messages', 'Total day minutes', 'Total day calls',
#        'Total day charge', 'Total eve minutes', 'Total eve calls',
#        'Total eve charge', 'Total night minutes', 'Total night calls',
#        'Total night charge', 'Total intl minutes', 'Total intl calls',
#        'Total intl charge', 'Customer service calls', 'Churn', 'State_AL',
#        'State_AR', 'State_AZ', 'State_CA', 'State_CO', 'State_CT', 'State_DC',
#        'State_DE', 'State_FL', 'State_GA', 'State_HI', 'State_IA', 'State_ID',
#        'State_IL', 'State_IN', 'State_KS', 'State_KY', 'State_LA', 'State_MA',
#        'State_MD', 'State_ME', 'State_MI', 'State_MN', 'State_MO', 'State_MS',
#        'State_MT', 'State_NC', 'State_ND', 'State_NE', 'State_NH', 'State_NJ',
#        'State_NM', 'State_NV', 'State_NY', 'State_OH', 'State_OK', 'State_OR',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 69 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Account length          667 non-null    int64
#  1   Area code               667 non-null    int64
#  2   International plan      667 non-null    int64
#  3   Voice mail plan         667 non-null    int64
#  4   Number vmail messages   667 non-null    int64
#  5   Total day minutes       667 non-null    float64
#  6   Total day calls         667 non-null    int64
#  7   Total day charge        667 non-null    float64
#  8   Total eve minutes       667 non-null    float64
#  9   Total eve calls         667 non-null    int64
#  10  Total eve charge        667 non-null    float64
#  11  Total night minutes     667 non-null    float64
#  12  Total night calls       667 non-null    int64
#  13  Total night charge      667 non-null    float64
# ...

# %%
df.to_csv(
    r"C:\Users\Anthony Bannerman\Documents\Codveda-Internship-Data-Science\Task_1_Data_Cleaning_Churn\churn_cleaned.csv",
    index=False
)

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Anthony Bannerman\\Documents\\Codveda-Internship-Data-Science\\Task_1_Data_Cleaning_Churn\\churn_cleaning.ipynb'
